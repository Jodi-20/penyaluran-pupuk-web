# %%
# Paper Web: Analisis Penyaluran Pupuk Bersubsidi

# 📌 Bagian 1: Pendahuluan
from IPython.display import display, Markdown, HTML
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive

display(Markdown("""
# Analisis Penyaluran Pupuk Bersubsidi

Analisis ini bertujuan untuk mengevaluasi tren penyaluran pupuk bersubsidi di Indonesia berdasarkan data kabupaten/kota, jenis pupuk, dan tahun. Fokus utamanya adalah melihat volume penyaluran berdasarkan jenis pupuk dan wilayah administratif.

Sumber data: Google Drive - file CSV berjudul `jml_penyaluran_pupuk_bersubsidi__kabupatenkota_data.csv`
"""))

# 📌 Bagian 2: Impor & Tampilkan Data
drive.mount('/content/drive')

# Ganti path ini sesuai lokasi file kamu di Google Drive
file_path = '/content/drive/MyDrive/analitika data/jml_penyaluran_pupuk_bersubsidi__kabupatenkota_data.csv'
df = pd.read_csv(file_path)

# Tampilkan seluruh data
display(Markdown("## Seluruh Data Penyaluran Pupuk Bersubsidi"))
display(HTML(df.to_html(max_rows=1000, max_cols=50, escape=False)))

# 📌 Bagian 3: Ringkasan Data
total_per_tahun = df.groupby("tahun")["volume"].sum().reset_index()
total_per_jenis = df.groupby("jenis_pupuk")["volume"].sum().reset_index()
top_kabupaten = df.groupby("nama_kabupaten_kota")["volume"].sum().sort_values(ascending=False).head(10).reset_index()

# Tampilkan tabel ringkasan
display(Markdown("## Ringkasan Data"))
display(Markdown("### Total Penyaluran per Tahun"))
display(total_per_tahun)

display(Markdown("### Total Penyaluran per Jenis Pupuk"))
display(total_per_jenis)

display(Markdown("### Top 10 Kabupaten/Kota dengan Volume Tertinggi"))
display(top_kabupaten)

# 📌 Bagian 4: Visualisasi Data
display(Markdown("## Visualisasi Data"))

# Grafik 1: Total Penyaluran per Tahun
plt.figure(figsize=(8,5))
plt.bar(total_per_tahun["tahun"].astype(str), total_per_tahun["volume"], color='skyblue')
plt.title("Total Penyaluran Pupuk per Tahun")
plt.xlabel("Tahun")
plt.ylabel("Volume (ton)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Grafik 2: Total per Jenis Pupuk
plt.figure(figsize=(8,5))
plt.bar(total_per_jenis["jenis_pupuk"], total_per_jenis["volume"], color='orange')
plt.title("Total Penyaluran Berdasarkan Jenis Pupuk")
plt.xlabel("Jenis Pupuk")
plt.ylabel("Volume (ton)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Grafik 3: Top 10 Kabupaten/Kota
plt.figure(figsize=(10,6))
plt.barh(top_kabupaten["nama_kabupaten_kota"], top_kabupaten["volume"], color='green')
plt.title("Top 10 Kabupaten/Kota dengan Penyaluran Tertinggi")
plt.xlabel("Volume (ton)")
plt.ylabel("Kabupaten/Kota")
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 📌 Bagian 5: Kesimpulan
display(Markdown("""
## Kesimpulan
- **Tahun 2022** menunjukkan volume penyaluran tertinggi.
- Jenis pupuk **UREA dan NPK** adalah yang paling banyak disalurkan.
- Kabupaten di Jawa Barat seperti **Indramayu** dan **Garut** mendominasi distribusi terbanyak.
"""))
# Out:
# # Analisis Penyaluran Pupuk Bersubsidi
#
# Analisis ini bertujuan untuk mengevaluasi tren penyaluran pupuk bersubsidi di Indonesia berdasarkan data kabupaten/kota, jenis pupuk, dan tahun. Fokus utamanya adalah melihat volume penyaluran berdasarkan jenis pupuk dan wilayah administratif.
#
# Sumber data: Google Drive - file CSV berjudul `jml_penyaluran_pupuk_bersubsidi__kabupatenkota_data.csv`
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ## Seluruh Data Penyaluran Pupuk Bersubsidi
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>kode_provinsi</th>
#       <th>nama_provinsi</th>
#       <th>kode_kabupaten_kota</th>
#       <th>nama_kabupaten_kota</th>
#       <th>jenis_pupuk</th>
#       <th>volume</th>
#       <th>satuan</th>
#       <th>tahun</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3201</td>
#       <td>KABUPATEN BOGOR</td>
#       <td>UREA</td>
#       <td>13997.760</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3201</td>
#       <td>KABUPATEN BOGOR</td>
#       <td>ZA</td>
#       <td>611.570</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3201</td>
#       <td>KABUPATEN BOGOR</td>
#       <td>NPK</td>
#       <td>9248.440</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3202</td>
#       <td>KABUPATEN SUKABUMI</td>
#       <td>UREA</td>
#       <td>30280.380</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3202</td>
#       <td>KABUPATEN SUKABUMI</td>
#       <td>ZA</td>
#       <td>784.260</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3202</td>
#       <td>KABUPATEN SUKABUMI</td>
#       <td>NPK</td>
#       <td>28340.220</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3203</td>
#       <td>KABUPATEN CIANJUR</td>
#       <td>UREA</td>
#       <td>32421.990</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3203</td>
#       <td>KABUPATEN CIANJUR</td>
#       <td>ZA</td>
#       <td>2430.430</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3203</td>
#       <td>KABUPATEN CIANJUR</td>
#       <td>NPK</td>
#       <td>24773.410</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3204</td>
#       <td>KABUPATEN BANDUNG</td>
#       <td>UREA</td>
#       <td>21076.220</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3204</td>
#       <td>KABUPATEN BANDUNG</td>
#       <td>ZA</td>
#       <td>3862.270</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3204</td>
#       <td>KABUPATEN BANDUNG</td>
#       <td>NPK</td>
#       <td>11250.100</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3205</td>
#       <td>KABUPATEN GARUT</td>
#       <td>UREA</td>
#       <td>54649.960</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3205</td>
#       <td>KABUPATEN GARUT</td>
#       <td>ZA</td>
#       <td>14538.780</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3205</td>
#       <td>KABUPATEN GARUT</td>
#       <td>NPK</td>
#       <td>45548.420</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3206</td>
#       <td>KABUPATEN TASIKMALAYA</td>
#       <td>UREA</td>
#       <td>38945.750</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3206</td>
#       <td>KABUPATEN TASIKMALAYA</td>
#       <td>ZA</td>
#       <td>1206.540</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3206</td>
#       <td>KABUPATEN TASIKMALAYA</td>
#       <td>NPK</td>
#       <td>25833.230</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3207</td>
#       <td>KABUPATEN CIAMIS</td>
#       <td>UREA</td>
#       <td>10466.300</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3207</td>
#       <td>KABUPATEN CIAMIS</td>
#       <td>ZA</td>
#       <td>87.610</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3207</td>
#       <td>KABUPATEN CIAMIS</td>
#       <td>NPK</td>
#       <td>12175.590</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3208</td>
#       <td>KABUPATEN KUNINGAN</td>
#       <td>UREA</td>
#       <td>13926.270</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3208</td>
#       <td>KABUPATEN KUNINGAN</td>
#       <td>ZA</td>
#       <td>894.260</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3208</td>
#       <td>KABUPATEN KUNINGAN</td>
#       <td>NPK</td>
#       <td>6289.870</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>25</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3209</td>
#       <td>KABUPATEN CIREBON</td>
#       <td>UREA</td>
#       <td>23297.430</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>26</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3209</td>
#       <td>KABUPATEN CIREBON</td>
#       <td>ZA</td>
#       <td>4073.020</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>27</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3209</td>
#       <td>KABUPATEN CIREBON</td>
#       <td>NPK</td>
#       <td>19101.000</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3210</td>
#       <td>KABUPATEN MAJALENGKA</td>
#       <td>UREA</td>
#       <td>32332.470</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>29</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3210</td>
#       <td>KABUPATEN MAJALENGKA</td>
#       <td>ZA</td>
#       <td>5379.470</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>30</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3210</td>
#       <td>KABUPATEN MAJALENGKA</td>
#       <td>NPK</td>
#       <td>16549.460</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>31</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3211</td>
#       <td>KABUPATEN SUMEDANG</td>
#       <td>UREA</td>
#       <td>15642.520</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>32</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3211</td>
#       <td>KABUPATEN SUMEDANG</td>
#       <td>ZA</td>
#       <td>755.020</td>
#       <td>TON</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>33</td>
#       <td>32</td>
#       <td>JAWA BARAT</td>
#       <td>3211</td>
#       <td>KABUPATEN SUMEDA
# ## Ringkasan Data
# ### Total Penyaluran per Tahun
#    tahun       volume
# 0   2021   857253.772
# 1   2022  1057852.150
# 2   2023   726507.710
# 3   2024   839973.230
# ### Total Penyaluran per Jenis Pupuk
#       jenis_pupuk       volume
# 0             NPK  1388510.210
# 1  ORGANIK GRANUL    23271.120
# 2   PUPUK ORGANIK      649.670
# 3           SP-36    31664.440
# 4            UREA  1967007.460
# 5              ZA    70483.962
# ### Top 10 Kabupaten/Kota dengan Volume Tertinggi
#      nama_kabupaten_kota     volume
# 0    KABUPATEN INDRAMAYU  425082.79
# 1        KABUPATEN GARUT  406826.37
# 2     KABUPATEN KARAWANG  324948.45
# 3  KABUPATEN TASIKMALAYA  280949.03
# 4       KABUPATEN SUBANG  278284.38
# 5      KABUPATEN CIANJUR  236536.31
# 6     KABUPATEN SUKABUMI  230072.59
# 7   KABUPATEN MAJALENGKA  214188.00
# 8      KABUPATEN CIREBON  178641.91
# 9      KABUPATEN BANDUNG  137695.97
# ## Visualisasi Data
# ## Kesimpulan
# - **Tahun 2022** menunjukkan volume penyaluran tertinggi.
# - Jenis pupuk **UREA dan NPK** adalah yang paling banyak disalurkan.
# - Kabupaten di Jawa Barat seperti **Indramayu** dan **Garut** mendominasi distribusi terbanyak.
